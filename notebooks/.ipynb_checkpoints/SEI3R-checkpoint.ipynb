# %% [markdown]
# # SEI3R
#
#
# SEI3R is another modification of the compartmental model structure which now separates the infected population into three categories, mild ($I_1$), severe ($I_2$), and critical ($I_3$).

# %% [markdown]
# The dynamics of this system are defined by the following equations:
#
#
# $$\frac{d}{dt}S_t = - (1 - u) \frac{1}{N_t} \sum_{i=1}^3 \beta_i I_{i,t}S_t$$
#
# $$\frac{d}{dt}E = (1 - u) \frac{1}{N_t} \sum_{i=1}^3 \beta_i I_{i,t}S_t - \alpha E_t $$
#
# $$\frac{d}{dt} I_{1,t} = \alpha E_t -p_1 I_{1,t} - \gamma_1 I_{1,t}$$
#
#
# $$\frac{d}{dt} I_{2,t} =  p_1 I_{1,t} -p_2 I_{2,t} - \gamma_2 I_{2,t}$$
#
#
# $$\frac{d}{dt} I_{3,t} =  p_2 I_{2,t} -p_3 I_{3,t} - \gamma_3 I_{3,t}$$
#
#
# $$\frac{d}{dt} R_{t} = \gamma_1 I_{1,t} + \gamma_2 I_{2,t} +  \gamma_3 I_{3,t}$$

# %% [markdown]
# This model is introduced in https://arxiv.org/abs/2003.13221, and we adapt it for use in Pyro in the following notebook.

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import pyro
import pyro.distributions as dist
from pyro.contrib.epidemiology import CompartmentalModel, binomial_dist, infection_dist

# %matplotlib inline
#assert pyro.__version__.startswith('1.5.0') # I have 1.5.1, hopefully not a problem to comment this out. 
torch.set_default_dtype(torch.double)  # Required for MCMC inference.
pyro.enable_validation(True)  # Always a good idea.
smoke_test = ('CI' in os.environ)

# %%
pyro.__version__
# Out:
# '1.5.0'

# %%
# check https://github.com/SwapneelM/covid/blob/master/SEIR/seir.py for help. 
class SimpleSEI3RModel(CompartmentalModel):
    """
    Susceptible-Exposed-Infected1-Infected2-Infected3-Recovered-(Dead) model.


    Because the transitions are not simple linear succession, this model
    implements a custom :meth:`compute_flows()` method.

    :param int population: Total ``population = S + E + I3 + R + D``.
    :param float incubation_time: Mean incubation time (duration in state
        ``E``). Must be greater than 1.
    :param float recovery_time: Mean recovery time (duration in state
        ``I``). Must be greater than 1.
    :param float mortality_rate: Portion of infections resulting in death.
        Must be in the open interval ``(0, 1)``.
    :param iterable data: Time series of new observed infections. Each time
        step is Binomial distributed between 0 and the number of ``S -> E``
        transitions. This allows false negative but no false positives.
    """

    def __init__(self, population, incubation_time, recovery_time,
                 mortality_rate, data):
        compartments = ("S", "E", "I", "I2", "I3", "D")  # R is implicit.
        duration = len(data)
        super().__init__(compartments, duration, population)

        assert isinstance(incubation_time, float)
        assert incubation_time > 1
        self.incubation_time = incubation_time

        assert isinstance(recovery_time, float)
        assert recovery_time > 1
        self.recovery_time = recovery_time

        assert isinstance(mortality_rate, float)
        assert 0 < mortality_rate < 1
        self.mortality_rate = mortality_rate

        self.data = data

    def global_model(self):
        tau_e = self.incubation_time
        tau_i = self.recovery_time
        mu = self.mortality_rate
        R0 = pyro.sample("R0", dist.LogNormal(0., 1.))
        rho = pyro.sample("rho", dist.Beta(10, 10))
        return R0, tau_e, tau_i, mu, rho

    def initialize(self, params):
        # Start with a single infection ( at stage 1) .
        # pretty ambiguous. Check with paper see if they do something different. 
        return {"S": self.population - 1, "E": 0, "I": 1, "I2":0, "I3":0, "D": 0}

    def transition(self, params, state, t):
        """
        How we go from one compartment to another. After definining changes we update compartments. 
        
        """
        R0, tau_e, tau_i, mu, rho = params # add the other ones from paper
        p1 = .5
        p2 = .5
        gamma1 = .2
        gamma2 = .3
        gamma3 = .5
        kappa = 0.005

        # Sample flows between compartments.
        S2E = pyro.sample("S2E_{}".format(t),
                          infection_dist(individual_rate=R0 / tau_i,
                                         num_susceptible=state["S"],
                                         num_infectious=state["I"],
                                         population=self.population))
        
        E2I = pyro.sample("E2I_{}".format(t),
                          binomial_dist(state["E"], 1 / tau_e))
        
        I2I2 = pyro.sample("I2I2_{}".format(t),
                          binomial_dist(state["I"], p1))
        
        I2R = pyro.sample("I2R_{}".format(t),
                          binomial_dist(state["I"], gamma1))
       
        I22I3 = pyro.sample("I22I3_{}".format(t),
                          binomial_dist(state["I2"], p2))
        
        I22R = pyro.sample("I22R_{}".format(t),
                          binomial_dist(state["I2"], gamma2))
        
        
        I32R = pyro.sample("I32R_{}".format(t),
                          binomial_dist(state["I3"], gamma3))
        
        I32D = pyro.sample("I32D_{}".format(t),
                          binomial_dist(state["I3"], kappa))
        
        
        # Of the 1/tau_i expected recoveries-or-deaths, a portion mu die and
        # the remaining recover. Alternatively we could model this with a
        # Multinomial distribution I2_ and extract the two components I2D and
        # I2R, however the Multinomial distribution does not currently
        # implement overdispersion or moment matching.
        

        # update compartments. 
        state["S"] = state["S"] - S2E
        state["E"] = state["E"] + S2E - E2I
        state["I"] = state["I"] + E2I - I2R - I2I2
        state["I2"] = state["I2"] + I2I2 - I22R - I22I3
        state["I3"] = state["I3"] + I22I3 - I32R - I32D
        state["D"] = state["D"] + I32D
        
        
        
        

        # Condition on observations.
        t_is_observed = isinstance(t, slice) or t < self.duration
        pyro.sample("obs_{}".format(t),
                    binomial_dist(S2E, rho),
                    obs=self.data[t] if t_is_observed else None)

# %% [markdown]
#         flows = {}
#         flow = 0
#         for source, destin in zip(self.compartments, self.compartments[1:] + ("R",)):
#             flow = prev[source] - curr[source] + flow
#             flows["{}2{}_{}".format(source, destin, t)] = flow
#         return flows

# %%
class SimpleSEIRDModel(CompartmentalModel):
    """
    Susceptible-Exposed-Infected-Recovered-Dead model.

    To customize this model we recommend forking and editing this class.

    This is a stochastic discrete-time discrete-state model with four
    compartments: "S" for susceptible, "E" for exposed, "I" for infected, "D"
    for deceased individuals, and "R" for recovered individuals (the recovered
    individuals are implicit: ``R = population - S - E - I - D``) with
    transitions ``S -> E -> I -> R`` and ``I -> D``.

    Because the transitions are not simple linear succession, this model
    implements a custom :meth:`compute_flows()` method.

    :param int population: Total ``population = S + E + I + R + D``.
    :param float incubation_time: Mean incubation time (duration in state
        ``E``). Must be greater than 1.
    :param float recovery_time: Mean recovery time (duration in state
        ``I``). Must be greater than 1.
    :param float mortality_rate: Portion of infections resulting in death.
        Must be in the open interval ``(0, 1)``.
    :param iterable data: Time series of new observed infections. Each time
        step is Binomial distributed between 0 and the number of ``S -> E``
        transitions. This allows false negative but no false positives.
    """

    def __init__(self, population, incubation_time, recovery_time,
                 mortality_rate, data):
        compartments = ("S", "E", "I", "D")  # R is implicit.
        duration = len(data)
        super().__init__(compartments, duration, population)

        assert isinstance(incubation_time, float)
        assert incubation_time > 1
        self.incubation_time = incubation_time

        assert isinstance(recovery_time, float)
        assert recovery_time > 1
        self.recovery_time = recovery_time

        assert isinstance(mortality_rate, float)
        assert 0 < mortality_rate < 1
        self.mortality_rate = mortality_rate

        self.data = data

    def global_model(self):
        tau_e = self.incubation_time
        tau_i = self.recovery_time
        mu = self.mortality_rate
        R0 = pyro.sample("R0", dist.LogNormal(0., 1.))
        rho = pyro.sample("rho", dist.Beta(10, 10))
        return R0, tau_e, tau_i, mu, rho

    def initialize(self, params):
        # Start with a single infection.
        return {"S": self.population - 1, "E": 0, "I": 1, "D": 0}

    def transition(self, params, state, t):
        R0, tau_e, tau_i, mu, rho = params

        # Sample flows between compartments.
        S2E = pyro.sample("S2E_{}".format(t),
                          infection_dist(individual_rate=R0 / tau_i,
                                         num_susceptible=state["S"],
                                         num_infectious=state["I"],
                                         population=self.population))
        print("Transition S2E", S2E)
        E2I = pyro.sample("E2I_{}".format(t),
                          binomial_dist(state["E"], 1 / tau_e))
        # Of the 1/tau_i expected recoveries-or-deaths, a portion mu die and
        # the remaining recover. Alternatively we could model this with a
        # Multinomial distribution I2_ and extract the two components I2D and
        # I2R, however the Multinomial distribution does not currently
        # implement overdispersion or moment matching.
        
        # Implicit part, and split flow. Will get much more complicated here when I include the multiple I values!
        
        I2D = pyro.sample("I2D_{}".format(t),
                          binomial_dist(state["I"], mu / tau_i))
        I2R = pyro.sample("I2R_{}".format(t),
                          binomial_dist(state["I"] - I2D, 1 / tau_i))

        # Update compartments with flows.
        state["S"] = state["S"] - S2E
        self.S2E = S2E
        state["E"] = state["E"] + S2E - E2I
        state["I"] = state["I"] + E2I - I2R - I2D
        state["D"] = state["D"] + I2D

        # Condition on observations.
        t_is_observed = isinstance(t, slice) or t < self.duration
        pyro.sample("obs_{}".format(t),
                    binomial_dist(S2E, rho),
                    obs=self.data[t] if t_is_observed else None)

    def compute_flows(self, prev, curr, t):
        S2E = prev["S"] - curr["S"]  # S can only go to E.
        S2E = self.S2E
        print("CF S2E", S2E)
        
        I2D = curr["D"] - prev["D"]  # D can only have come from I.
        # We deduce the remaining flows by conservation of mass:
        #   curr - prev = inflows - outflows
        E2I = prev["E"] - curr["E"] + S2E
        I2R = prev["I"] - curr["I"] + E2I - I2D #implicit since there is no "R" compartment
        return {
            "S2E_{}".format(t): S2E,
            "E2I_{}".format(t): E2I,
            "I2D_{}".format(t): I2D,
            "I2R_{}".format(t): I2R,
        }

# %% [markdown]
# ## Generating Data
#
# What if I don't want to do this?

# %%
population = 10000
recovery_time = 10.
incubation_time = 3.
empty_data = [None] * 150
mortality_rate = .004 
model = SimpleSEI3RModel(population, incubation_time, recovery_time, mortality_rate, empty_data)

# We'll repeatedly generate data until a desired number of infections is found.
pyro.set_rng_seed(20200709)
for attempt in range(100):
    synth_data = model.generate({"R0": 1.5})
    total_infections = synth_data["S2E"].sum().item()
    print("total exposed:", total_infections)
    if 400 <= total_infections <= 6000:
        break
print("Simulated {} infections after {} attempts".format(total_infections, 1 + attempt))
# Out:
# total exposed: 3.0
# Warmup:   0%|          | 0/400 [03:59, ?it/s]
# total exposed: 3.0
# total exposed: 3.0
# total exposed: 6.0
# total exposed: 4.0
# total exposed: 4.0
# total exposed: 2.0
# total exposed: 0.0
# total exposed: 1.0
# total exposed: 5.0
# total exposed: 1.0
# total exposed: 2.0
# total exposed: 6.0
# total exposed: 0.0
# total exposed: 6.0
# total exposed: 2.0
# total exposed: 1.0
# total exposed: 2.0
# total exposed: 4.0
# total exposed: 2.0
# total exposed: 1.0
# total exposed: 2.0
# total exposed: 3.0
# total exposed: 2.0
# total exposed: 1.0
# total exposed: 2.0
# total exposed: 0.0
# total exposed: 1.0
# total exposed: 1.0
# total exposed: 5.0
# total exposed: 2.0
# total exposed: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-0042bfd0d179> in <module>
#       9 pyro.set_rng_seed(20200709)
#      10 for attempt in range(100):
# ---> 11     synth_data = model.generate({"R0": 1.5})
#      12     total_infections = synth_data["S2E"].sum().item()
#      13     print("total exposed:", total_infections)
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/contrib/epidemiology/compartmental.py in generate(self, fixed)
#     345         model = self._generative_model
#     346         model = poutine.condition(model, fixed)
# --> 347         trace = poutine.trace(model).get_trace()
#     348         samples = OrderedDict((name, site["value"])
#     349                               for name, site in trace.nodes.items()
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/trace_messenger.py in get_trace(self, *args, **kwargs)
#     185         Calls this poutine and returns its trace instead of the function's return value.
#     186         """
# --> 187         self(*args, **kwargs)
#     188         return self.msngr.get_trace()
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/trace_messenger.py in __call__(self, *args, **kwargs)
#     163                                       args=args, kwargs=kwargs)
#     164             try:
# --> 165                 ret = self.fn(*args, **kwargs)
#     166             except (ValueError, RuntimeError) as e:
#     167                 exc_type, exc_value, traceback = sys.exc_info()
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#      14
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/contrib/epidemiology/compartmental.py in _generative_model(self, forecast)
#     857             with self.region_plate:
#     858                 for name in self.compartments:
# --> 859                     pyro.deterministic("{}_{}".format(name, t), state[name], event_dim=0)
#     860
#     861         self._clear_plates()
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/primitives.py in deterministic(name, value, event_dim)
#     146     """
#     147     event_dim = value.ndim if event_dim is None else event_dim
# --> 148     return sample(name, dist.Delta(value, event_dim=event_dim).mask(False),
#     149                   obs=value, infer={"_deterministic": True})
#     150
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/distributions/distribution.py in __call__(cls, *args, **kwargs)
#      15             if result is not None:
#      16                 return result
# ---> 17         return super().__call__(*args, **kwargs)
#      18
#      19
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/distributions/delta.py in __init__(self, v, log_density, event_dim, validate_args)
#      36         event_shape = v.shape[batch_dim:]
#      37         if isinstance(log_density, numbers.Number):
# ---> 38             log_density = torch.full(batch_shape, log_density, dtype=v.dtype, device=v.device)
#      39         elif validate_args and log_density.shape != batch_shape:
#      40             raise ValueError('Expected log_density.shape = {}, actual {}'.format(
#
# KeyboardInterrupt:

# %% [markdown]
# For the model to work, it requires S, S2I, I, I2R, obs (noisy S2I), R0, and rho.
#
#
# At the moment, all of these things are synthetically generated, after we first specify R0, rho and population.
#
# For real world, I'll try this now, but we set:
#
# S2I = obs, and use reported values for the others. In essence we no longer use the noisy observations and assume whatever is reported is right?
#
# I'm not sure if the model will work if we do not specify R0 or rho, so will have to try this and find out.

# %%
for key, value in sorted(synth_data.items()):
    print("{}.shape = {}".format(key, tuple(value.shape)))
# Out:
# D.shape = (150,)
# E.shape = (150,)
# E2I.shape = (150,)
# I.shape = (150,)
# I2.shape = (150,)
# I22I3.shape = (150,)
# I22R.shape = (150,)
# I2I2.shape = (150,)
# I2R.shape = (150,)
# I3.shape = (150,)
# I32D.shape = (150,)
# I32R.shape = (150,)
# R0.shape = ()
# S.shape = (150,)
# S2E.shape = (150,)
# obs.shape = (150,)
# rho.shape = ()

# %%
plt.figure(figsize=(8,4))
for name, value in sorted(synth_data.items()):
    if value.dim():
        plt.plot(value, label=name)
plt.xlim(0, len(empty_data) - 1)
plt.ylim(0.8, None)
plt.xlabel("time step")
plt.ylabel("individuals")
plt.yscale("log")
plt.legend(loc="best")
plt.title("Synthetic time series")
plt.tight_layout()

# %% [markdown]
# ## Inference

# %%
# what if we only have obs? can we estimate using just that? 
obs = synth_data["obs"]
model = SimpleSEI3RModel(population, incubation_time, recovery_time, mortality_rate, obs)

# %%
obs.shape
# Out:
# torch.Size([150])

# %%
# %%time
losses = model.fit_svi(num_steps=101 if smoke_test else 2001,
                       jit=True)
# Out:
# INFO 	 Failed to find feasible hypothesis after site I2I2_1. Retrying...
# INFO 	 Failed to find feasible hypothesis after site I2I2_1. Retrying...
# INFO 	 Failed to find feasible hypothesis after site I2I2_1. Retrying...
# INFO 	 Failed to find feasible hypothesis after site I2I2_1. Retrying...
# INFO 	 Failed to find feasible hypothesis after site I2I2_1. Retrying...
# INFO 	 Failed to find feasible hypothesis after site I2I2_1. Retrying...
# INFO 	 Failed to find feasible hypothesis after site I2I2_1. Retrying...
# INFO 	 Failed to find feasible hypothesis after site I2I2_1. Retrying...
# INFO 	 Failed to find feasible hypothesis after site I2I2_1. Retrying...
# ---------------------------------------------------------------------------
# SMCFailed                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/contrib/epidemiology/compartmental.py in fit_svi(self, num_samples, num_steps, num_particles, learning_rate, learning_rate_decay, betas, haar, init_scale, guide_rank, jit, log_every, **options)
#     423                              if k.startswith("heuristic_")}
#     424         assert not options, "unrecognized options: {}".format(", ".join(options))
# --> 425         init_strategy = self._heuristic(haar, **heuristic_options)
#     426
#     427         # Configure variational inference.
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/contrib/epidemiology/compartmental.py in _heuristic(self, haar, **options)
#     714     def _heuristic(self, haar, **options):
#     715         with poutine.block():
# --> 716             init_values = self.heuristic(**options)
#     717         assert isinstance(init_values, dict)
#     718         assert "auxiliary" in init_values, \
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/contrib/epidemiology/compartmental.py in heuristic(self, num_particles, ess_threshold, retries)
#     691                 smc.init()
#     692                 for t in range(1, self.duration):
# --> 693                     smc.step()
#     694                 break
#     695             except SMCFailed as e:
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/infer/smcfilter.py in step(self, *args, **kwargs)
#      92             model_trace = poutine.trace(model).get_trace(self.state, *args, **kwargs)
#      93
# ---> 94         self._update_weights(model_trace, guide_trace)
#      95         self._maybe_importance_resample()
#      96
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/infer/smcfilter.py in _update_weights(self, model_trace, guide_trace)
#     121                 self.state._log_weights += log_p - log_q
#     122                 if not (self.state._log_weights.max() > -math.inf):
# --> 123                     raise SMCFailed("Failed to find feasible hypothesis after site {}"
#     124                                     .format(name))
#     125
#
# SMCFailed: Failed to find feasible hypothesis after site I2I2_1

# %%
plt.figure(figsize=(8, 3))
plt.plot(losses)
plt.xlabel("SVI step")
plt.ylabel("loss")
plt.ylim(min(losses), max(losses[50:]));

# %%
for key, value in sorted(model.samples.items()):
    print("{}.shape = {}".format(key, tuple(value.shape)))

# %%
# %%time
samples = model.predict()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <timed exec> in <module>
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/contrib/epidemiology/compartmental.py in predict(self, forecast)
#     616             _require_double_precision()
#     617         if not self.samples:
# --> 618             raise RuntimeError("Missing samples, try running .fit_mcmc() first")
#     619
#     620         samples = self.samples
#
# RuntimeError: Missing samples, try running .fit_mcmc() first

# %%
names = ["R0", "rho"]
fig, axes = plt.subplots(2, 1, figsize=(5, 5))
axes[0].set_title("Posterior estimates of global parameters")
for ax, name in zip(axes, names):
    truth = synth_data[name]
    sns.distplot(samples[name], ax=ax, label="posterior")
    ax.axvline(truth, color="k", label="truth")
    ax.set_xlabel(name)
    ax.set_yticks(())
    ax.legend(loc="best")
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-686beeec444c> in <module>
#       4 for ax, name in zip(axes, names):
#       5     truth = synth_data[name]
# ----> 6     sns.distplot(samples[name], ax=ax, label="posterior")
#       7     ax.axvline(truth, color="k", label="truth")
#       8     ax.set_xlabel(name)
#
# NameError: name 'samples' is not defined

# %% [markdown]
# ## MCMC

# %%
mcmc = model.fit_mcmc(num_samples=4 if smoke_test else 200,
                      jit_compile=True,)
# Out:
# INFO 	 Running inference...
# Warmup:   0%|          | 0/400 [00:00, ?it/s]INFO 	 Heuristic init: R0=1.9, rho=0.131
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/trace_messenger.py in __call__(self, *args, **kwargs)
#     164             try:
# --> 165                 ret = self.fn(*args, **kwargs)
#     166             except (ValueError, RuntimeError) as e:
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/contrib/epidemiology/compartmental.py in _relaxed_model(self)
#    1030             t = slice(0, T, 1)  # Used to slice data tensors.
# -> 1031             self._transition_bwd(params, prev, curr, t)
#    1032
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/contrib/epidemiology/compartmental.py in _transition_bwd(self, params, prev, curr, t)
#     835                 if not torch.allclose(state[key], curr[key]):
# --> 836                     raise ValueError("Incorrect state['{}'] update in .transition(), "
#     837                                      "check that .transition() matches .compute_flows()."
#
# ValueError: Incorrect state['I'] update in .transition(), check that .transition() matches .compute_flows().
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-ee8fb1a049de> in <module>
# ----> 1 mcmc = model.fit_mcmc(num_samples=4 if smoke_test else 200,
#       2                       jit_compile=True,)
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/contrib/epidemiology/compartmental.py in fit_mcmc(self, **options)
#     583         options.setdefault("disable_validation", None)
#     584         mcmc = MCMC(kernel, **options)
# --> 585         mcmc.run()
#     586         self.samples = mcmc.get_samples()
#     587         if haar:
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#      14
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/infer/mcmc/api.py in run(self, *args, **kwargs)
#     378         with optional(pyro.validation_enabled(not self.disable_validation),
#     379                       self.disable_validation is not None):
# --> 380             for x, chain_id in self.sampler.run(*args, **kwargs):
#     381                 if num_samples[chain_id] == 0:
#     382                     num_samples[chain_id] += 1
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/infer/mcmc/api.py in run(self, *args, **kwargs)
#     165             logger = initialize_logger(logger, "", progress_bar)
#     166             hook_w_logging = _add_logging_hook(logger, progress_bar, self.hook)
# --> 167             for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, hook_w_logging,
#     168                                        i if self.num_chains > 1 else None,
#     169                                        *args, **kwargs):
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/infer/mcmc/api.py in _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs)
#     109
#     110 def _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs):
# --> 111     kernel.setup(warmup_steps, *args, **kwargs)
#     112     params = kernel.initial_params
#     113     # yield structure (key, value.shape) of params
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/infer/mcmc/hmc.py in setup(self, warmup_steps, *args, **kwargs)
#     301         self._warmup_steps = warmup_steps
#     302         if self.model is not None:
# --> 303             self._initialize_model_properties(args, kwargs)
#     304         if self.initial_params:
#     305             z = {k: v.detach() for k, v in self.initial_params.items()}
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/infer/mcmc/hmc.py in _initialize_model_properties(self, model_args, model_kwargs)
#     243
#     244     def _initialize_model_properties(self, model_args, model_kwargs):
# --> 245         init_params, potential_fn, transforms, trace = initialize_model(
#     246             self.model,
#     247             model_args,
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/infer/mcmc/util.py in initialize_model(model, model_args, model_kwargs, transforms, max_plate_nesting, jit_compile, jit_options, skip_jit_warnings, num_chains, init_strategy, initial_params)
#     386                          first_available_dim=-1 - max_plate_nesting)
#     387     prototype_model = poutine.trace(InitMessenger(init_strategy)(model))
# --> 388     model_trace = prototype_model.get_trace(*model_args, **model_kwargs)
#     389     has_enumerable_sites = False
#     390     prototype_samples = {}
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/trace_messenger.py in get_trace(self, *args, **kwargs)
#     185         Calls this poutine and returns its trace instead of the function's return value.
#     186         """
# --> 187         self(*args, **kwargs)
#     188         return self.msngr.get_trace()
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/trace_messenger.py in __call__(self, *args, **kwargs)
#     169                 exc = exc_type(u"{}\n{}".format(exc_value, shapes))
#     170                 exc = exc.with_traceback(traceback)
# --> 171                 raise exc from e
#     172             self.msngr.trace.add_node("_RETURN", name="_RETURN", type="return", value=ret)
#     173         return ret
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/trace_messenger.py in __call__(self, *args, **kwargs)
#     163                                       args=args, kwargs=kwargs)
#     164             try:
# --> 165                 ret = self.fn(*args, **kwargs)
#     166             except (ValueError, RuntimeError) as e:
#     167                 exc_type, exc_value, traceback = sys.exc_info()
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#      14
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#      14
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#      14
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/contrib/epidemiology/compartmental.py in _relaxed_model(self)
#    1029         with self.time_plate:
#    1030             t = slice(0, T, 1)  # Used to slice data tensors.
# -> 1031             self._transition_bwd(params, prev, curr, t)
#    1032
#    1033         # Apply final likelihood.
#
# /scratch/nsk367/anaconda3/envs/pyro/lib/python3.8/site-packages/pyro/contrib/epidemiology/compartmental.py in _transition_bwd(self, params, prev, curr, t)
#     834             for key in self.compartments:
#     835                 if not torch.allclose(state[key], curr[key]):
# --> 836                     raise ValueError("Incorrect state['{}'] update in .transition(), "
#     837                                      "check that .transition() matches .compute_flows()."
#     838                                      .format(key))
#
# ValueError: Incorrect state['I'] update in .transition(), check that .transition() matches .compute_flows().
#               Trace Shapes:
#                Param Sites:
#               Sample Sites:
#                     R0 dist     |
#                       value     |
#                    rho dist     |
#                       value     |
#              auxiliary dist     |   6 150
#                       value     |   6 150
#                    I2R dist     | 150
#                       value     | 150
#                   I22R dist     | 150
#                       value     | 150
#                   I32R dist     | 150
#                       value     | 150
#                   time dist     |
#                       value 150 |
#   S2E_slice(0, 150, 1) dist 150 |
#                       value 150 |
#   E2I_slice(0, 150, 1) dist 150 |
#                       value 150 |
#  I2I2_slice(0, 150, 1) dist 150 |
#                       value 150 |
#   I2R_slice(0, 150, 1) dist 150 |
#                       value 150 |
# I22I3_slice(0, 150, 1) dist 150 |
#                       value 150 |
#  I22R_slice(0, 150, 1) dist 150 |
#                       value 150 |
#  I32R_slice(0, 150, 1) dist 150 |
#                       value 150 |
#  I32D_slice(0, 150, 1) dist 150 |
#                       value 150 |
#   obs_slice(0, 150, 1) dist 150 |
#                       value 150 |

# %% [markdown]
# ## Prediction

# %%
# %%time
samples = model.predict()

# %%
for key, value in sorted(samples.items()):
    print("{}.shape = {}".format(key, tuple(value.shape)))

# %%
names = ["R0", "rho"]
fig, axes = plt.subplots(2, 1, figsize=(5, 5))
axes[0].set_title("Posterior estimates of global parameters")
for ax, name in zip(axes, names):
    truth = synth_data[name]
    sns.distplot(samples[name], ax=ax, label="posterior")
    ax.axvline(truth, color="k", label="truth")
    ax.set_xlabel(name)
    ax.set_yticks(())
    ax.legend(loc="best")
plt.tight_layout()

# %% [markdown]
# ## Forecasting

# %%
# %time
samples = model.predict(forecast=30)

# %%
def plot_forecast(samples):
    duration = len(empty_data)
    forecast = samples["S"].size(-1) - duration
    num_samples = len(samples["R0"])

    time = torch.arange(duration + forecast)
    S2E = samples["S2E"]
    median = S2E.median(dim=0).values
    p05 = S2E.kthvalue(int(round(0.5 + 0.05 * num_samples)), dim=0).values
    p95 = S2E.kthvalue(int(round(0.5 + 0.95 * num_samples)), dim=0).values

    plt.figure(figsize=(8, 4))
    plt.fill_between(time, p05, p95, color="red", alpha=0.3, label="90% CI")
    plt.plot(time, median, "r-", label="median")
    plt.plot(time[:duration], obs, "k.", label="observed")
    plt.plot(time[:duration], synth_data["S2E"], "k--", label="truth")
    plt.axvline(duration - 0.5, color="gray", lw=1)
    plt.xlim(0, len(time) - 1)
    plt.ylim(0, None)
    plt.xlabel("day after first infection")
    plt.ylabel("new infections per day")
    plt.title("New infections in population of {}".format(population))
    plt.legend(loc="upper left")
    plt.tight_layout()

plot_forecast(samples)

# %% [markdown]
# A suggestion of the authors is to use MCMC rather than SVI to estimate, and this will produce better results with only a little longer compute time. I will avoid doing that for the moment, because I would consider it a higher priority to figure out how to run this model with actual data, rather than manufactured.

# %%
synth_data

# %%
samples['R0'].mean()
